# %% [markdown]
# <a href="https://colab.research.google.com/github/KAnejjar/python_projects/blob/main/Human%20Image%20Generation%20with%20Animal%20Feature/interface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install streamlit

# %%
# !pip install streamlit pyngrok

# %%
import streamlit as st
from PIL import Image

# Placeholder function to simulate GAN output (replace this with your GAN model integration)
def generate_image(text_prompt, animal_feature_intensity):
    # Placeholder: Load a sample image
    # Replace this with actual image generation using your GAN
    img = Image.open("sample_output.jpg")  # Replace with dynamically generated output
    return img

# Streamlit Interface
st.title("Human Image Generator with Animal Features 🐾")
st.subheader("Generate realistic human images with customizable animal features!")

# User Inputs
text_prompt = st.text_input("Enter a description (e.g., 'A woman with cat ears'): ")
animal_feature_intensity = st.slider(
    "Adjust Animal Feature Intensity", 0, 100, 50
)

# Button generating the image
if st.button("Generate Image"):
    with st.spinner("Generating image..."):
        # Generate the image
        output_image = generate_image(text_prompt, animal_feature_intensity)
        st.image(output_image, caption="Generated Image", use_column_width=True)

# Footer
st.write("Created with ❤️ using GANs and Streamlit")
# Out:
# 2024-12-10 11:55:34.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 11:55:34.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 11:55:34.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 11:55:34.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 11:55:34.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 11:55:34.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 11:55:34.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import ipywidgets as widgets
from IPython.display import display, Image
import random  # Just for generating a placeholder image (for now)

# Create a description (textarea) widget
text_prompt = widgets.Textarea(
    value='',
    placeholder='Enter a description (e.g., "A woman with cat ears")',
    description='Description:',
    disabled=False,
    layout=widgets.Layout(width='100%', height='100px')
)

# Slider widget for animal feature intensity
animal_feature_intensity = widgets.IntSlider(
    value=50,
    min=0,
    max=100,
    step=1,
    description='Intensity:',
    continuous_update=False,
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='100%')
)

# Button to trigger image generation
generate_button = widgets.Button(
    description="Generate Image",
    style={'button_color': 'lightblue'},
    layout=widgets.Layout(width='100%')
)

# Image display area (initially empty)
image_display = widgets.Output()

# Function to simulate image generation (for illustration)
def generate_image(b):
    # Simulate an image being generated based on input
    print(f"Generating image for: {text_prompt.value} with intensity {animal_feature_intensity.value}")
    # with image_display:
    #      display(Image(data=f"https://via.placeholder.com/300x300.png?text={random.randint(1,100)}"))

# Link the button to the generate_image function
generate_button.on_click(generate_image)

# Organize widgets into a layout using VBox and HBox
form_layout = widgets.VBox([
    text_prompt,
    animal_feature_intensity,
    generate_button,
    image_display
], layout=widgets.Layout(width='80%', margin='20px auto'))

# Display the form
display(form_layout)
# Out:
# ...
# Generating image for:  with intensity 10
# Generating image for:  with intensity 10
# Generating image for:  with intensity 10
